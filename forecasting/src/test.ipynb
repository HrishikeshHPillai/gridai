# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/hrishikeshhpillai/Documents/hrishi/gridai/forecasting/datasets/SolarPrediction2.csv", parse_dates=['datetime'], index_col = ['datetime'])
df
# Out:
#                      Radiation  Temperature  Pressure  Humidity  \
# datetime
# 2016-09-29 23:55:26       1.21           48     30.46        59
# 2016-09-29 23:50:23       1.21           48     30.46        58
# 2016-09-29 23:45:26       1.23           48     30.46        57
# 2016-09-29 23:40:21       1.21           48     30.46        60
# 2016-09-29 23:35:24       1.17           48     30.46        62
# ...                        ...          ...       ...       ...
# 2016-12-01 00:20:04       1.22           44     30.43       102
# 2016-12-01 00:15:01       1.17           44     30.42       102
# 2016-12-01 00:10:01       1.20           44     30.42       102
# 2016-12-01 00:05:02       1.23           44     30.42       101
# 2016-12-01 00:00:02       1.20           44     30.43       101
#
#                      WindDirection(Degrees)  Speed
# datetime
# 2016-09-29 23:55:26                  177.39   5.62
# 2016-09-29 23:50:23                  176.78   3.37
# ...

# %%
X = df[["Temperature", "Pressure", "Humidity", "WindDirection(Degrees)", "Speed"]]
X = X.sort_values(by="datetime", ascending=True)
X
# Out:
#                      Temperature  Pressure  Humidity  WindDirection(Degrees)  \
# datetime
# 2016-09-01 00:00:08           51     30.43       103                   77.27
# 2016-09-01 00:05:10           51     30.43       103                  153.44
# 2016-09-01 00:20:06           51     30.43       103                  142.04
# 2016-09-01 00:25:05           51     30.43       103                  144.12
# 2016-09-01 00:30:09           51     30.43       103                   67.42
# ...                          ...       ...       ...                     ...
# 2016-12-31 23:35:02           41     30.34        83                  238.94
# 2016-12-31 23:40:01           41     30.34        82                  236.79
# 2016-12-31 23:45:04           42     30.34        81                  218.28
# 2016-12-31 23:50:03           41     30.34        80                  215.23
# 2016-12-31 23:55:01           41     30.34        81                  215.56
#
#                      Speed
# ...

# %%
y = df[["Radiation"]]
y = y.sort_values(by="datetime", ascending=True)
y
# Out:
#                      Radiation
# datetime
# 2016-09-01 00:00:08       2.58
# 2016-09-01 00:05:10       2.83
# 2016-09-01 00:20:06       2.16
# 2016-09-01 00:25:05       2.21
# 2016-09-01 00:30:09       2.25
# ...                        ...
# 2016-12-31 23:35:02       1.22
# 2016-12-31 23:40:01       1.21
# 2016-12-31 23:45:04       1.21
# 2016-12-31 23:50:03       1.19
# 2016-12-31 23:55:01       1.21
#
# [32686 rows x 1 columns]

# %%
X_np = df[["Radiation","Temperature", "Pressure", "Humidity", "WindDirection(Degrees)", "Speed"]].to_numpy()

# %%
X_np
# Out:
# array([[  1.21,  48.  ,  30.46,  59.  , 177.39,   5.62],
#        [  1.21,  48.  ,  30.46,  58.  , 176.78,   3.37],
#        [  1.23,  48.  ,  30.46,  57.  , 158.75,   3.37],
#        ...,
#        [  1.2 ,  44.  ,  30.42, 102.  , 145.19,   9.  ],
#        [  1.23,  44.  ,  30.42, 101.  , 164.19,   7.87],
#        [  1.2 ,  44.  ,  30.43, 101.  ,  83.59,   3.37]])

# %%
X_np.shape
# Out:
# (32686, 6)

# %%
test_arr = []

for i in range(0, len(X_np)):
    test_arr.append(X_np[0:38])

# %%
test_arr = np.array(test_arr)

# %%
test_arr.shape
# Out:
# (32686, 38, 6)

# %%
test_arr[0]
# Out:
# array([[  1.21,  48.  ,  30.46,  59.  , 177.39,   5.62],
#        [  1.21,  48.  ,  30.46,  58.  , 176.78,   3.37],
#        [  1.23,  48.  ,  30.46,  57.  , 158.75,   3.37],
#        [  1.21,  48.  ,  30.46,  60.  , 137.71,   3.37],
#        [  1.17,  48.  ,  30.46,  62.  , 104.95,   5.62],
#        [  1.21,  48.  ,  30.46,  64.  , 120.2 ,   5.62],
#        [  1.2 ,  49.  ,  30.46,  72.  , 112.45,   6.75],
#        [  1.24,  49.  ,  30.46,  71.  , 122.97,   5.62],
#        [  1.23,  49.  ,  30.46,  80.  , 101.18,   4.5 ],
#        [  1.21,  49.  ,  30.46,  85.  , 141.87,   4.5 ],
#        [  1.23,  49.  ,  30.47,  93.  , 120.55,   2.25],
#        [  1.21,  49.  ,  30.47,  98.  , 144.19,   3.37],
#        [  1.22,  49.  ,  30.47,  99.  , 139.8 ,   6.75],
#        [  1.21,  50.  ,  30.47,  99.  , 140.92,   2.25],
#        [  1.23,  50.  ,  30.47,  99.  , 147.61,   5.62],
#        [  1.22,  50.  ,  30.47,  99.  , 113.78,   4.5 ],
# ...

# %%
import pandas as pd

df = pd.read_csv('/home/navneeth/Egopro/dnn/gridai/forecasting/datasets/complete_dataset.csv')

# %%
df
# Out:
#             date      demand        RRP  demand_pos_RRP  RRP_positive  \
# 0     2015-01-01   99635.030  25.633696       97319.240     26.415953
# 1     2015-01-02  129606.010  33.138988      121082.015     38.837661
# 2     2015-01-03  142300.540  34.564855      142300.540     34.564855
# 3     2015-01-04  104330.715  25.005560      104330.715     25.005560
# 4     2015-01-05  118132.200  26.724176      118132.200     26.724176
# ...          ...         ...        ...             ...           ...
# 2101  2020-10-02   99585.835  -6.076028       41988.240     26.980251
# 2102  2020-10-03   92277.025  -1.983471       44133.510     32.438156
# 2103  2020-10-04   94081.565  25.008614       88580.995     26.571687
# 2104  2020-10-05  113610.030  36.764701      106587.375     39.616015
# 2105  2020-10-06  122607.560  75.771059      122607.560     75.771059
#
#       demand_neg_RRP  RRP_negative  frac_at_neg_RRP  min_temperature  \
# ...
